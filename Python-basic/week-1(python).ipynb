# %%
print('Hello World')
#python is a case sensitive language
# Out:
# Hello World

# %%
print(3)
# Out:
# 3

# %%
print("erheinfsinvsio")
# Out:
# erheinfsinvsio

# %%
print(234.23)
# Out:
# 234.23

# %%
print(True)
# Out:
# True

# %%
print(122,'hello',True)
# Out:
# 122 hello True

# %%
print(123,'hello',78.90 , sep='%')
# Out:
# 123%hello%78.9

# %%
print('helo')
print('world')
# Out:
# helo
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print('hey')
# Out:
# hey

# %% [markdown]
# data type

# %%
#integer
print(8)
# 1*10^308
print(1e309)
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
#decimal/float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#Boolead
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print('hey my name is mayank mali')
# Out:
# hey my name is mayank mali

# %%
# complex number
print(5+7j)
# Out:
# (5+7j)

# %%
#list --> Array
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
# sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name' : 'mayank' , 'age' : 20 , 'Gender':'male'})
# Out:
# {'name': 'mayank', 'age': 20, 'Gender': 'male'}

# %%
type(3)
# Out:
# int

# %%
type('heuye')
# Out:
# str

# %% [markdown]
# Variables

# %%
name = 'mayank'
print(name)
# Out:
# mayank

# %%
a = 5
b = 6
print(a + b)
# Out:
# 11

# %%
#dynamic Typing
a =5

# Static typing
int a = 3
# Out:
#   File "<ipython-input-30-b4de881f8fac>", line 5
#     int a = 3
#         ^
# SyntaxError: invalid syntax

# %%
 ##dynamic Binding
 a = 5
 print(a)
 a = 'mayank'
 print(a)

 ## static binding
 InteractiveShellABC a = 4
 a = 'hey'
# Out:
# 5
# mayank

# %%
a = 1
b = 2
c = 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # **Comments**

# %%
a = 3
b = 7
print(a+b)
# here we add a and b
#this is a comment
# Out:
# 10

# %% [markdown]
# # KEywords & Identifiers

# %%
 #identifier
 #you can not start a name with any number
 # 1name = 'hey'  wrong
 name1 = 'mayank'
 print(name1)
 # you can use specail chars -> _
 #first-name = 'mayank'
 first_name = 'mayank'
 print(first_name)
 _ = 'mali'
 print(_)
# identifiers can not be keywordss
# Out:
# mayank
# mayank
# mali

# %% [markdown]
# # user input

# %%
#static software
# dynamic
input('enter your name')
input('enter email')
# Out:
# enter your namemayank mali
# enter emailmali@gamil.com
# 'mali@gamil.com'

# %%
#take inpout from user and stroe from the variable
# add the 2 variable
#print the result
f_num = int(input("enter a number"))
s_num = int(input("enter a second number"))
print(type(f_num), type(s_num))
print(f_num , s_num)
# add the variable
result = f_num + s_num
# print the result
print(result)
# Out:
# enter a number35
# enter a second number63
# <class 'int'> <class 'int'>
# 35 63
# 98

# %% [markdown]
# # TYpe - converstion

# %%
#implicit VS explicit
#implicit
print(5+5.6)
print(type(5),type(5.6))
#explicit
#str -> Int
type(int('4'))
##int(4+5j)

# int to str
type(str(5))

#float
float(4)
# Out:
# 10.6
# <class 'int'> <class 'float'>
# 4.0

# %% [markdown]
# # literals

# %%
 a = 0b1010 #binary literal
 b = 100 #decimals literal
 c = 0o310 #octal literal
 d = 0x12c #hexadecimal literal

 #float literal
 float_1 = 10.5
 float_2 = 1.5e2 # 1.5 * 10^2
 float_3 = 1.5e-3 #1.5*10^-3

 #complex literal
 x = 3.14j

 print(a)
# Out:
# 10

# %% [markdown]
# # String

# %%
string = "mayank"
string1 = 'mayannk'
char = "c"
multiline_str = """this is a multiline string with more than one line code ."""
unicode = u"\U0001f600\U0001f606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(string)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# mayank
# mayank
# c
# this is a multiline string with more than one line code .
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a :",a)
print("b :",b)
# Out:
# a : 5
# b : 10

# %%
a = None
print(a)
# Out:
# None
